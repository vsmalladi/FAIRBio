# %% [markdown]
# <a href="https://colab.research.google.com/github/vsmalladi/FAIRBio/blob/main/fairbio/notebooks/ga4gh_registries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Get list of trs docker images from biocontainers

# %%
# !pip install git+https://github.com/vsmalladi/FAIRBio
# Out:
# ...
#   Cloning https://github.com/vsmalladi/FAIRBio to /tmp/pip-req-build-_i58_t2s
#   Running command git clone --filter=blob:none --quiet https://github.com/vsmalladi/FAIRBio /tmp/pip-req-build-_i58_t2s
#   Resolved https://github.com/vsmalladi/FAIRBio to commit 24cf3e9b78f6f8dcfd5e716271418a4868806310
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fairbio: filename=fairbio-0.1.0-py3-none-any.whl size=16992 sha256=8192809c8c0808e5c7e7395a48d7d8b8ce2086a0eaa4d238204dc8194db6ac6d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-13caqoi9/wheels/f3/84/13/94ff52c8516b324e2df2c98669fde34a6fcab49ec51757c29a
# Successfully built fairbio
# ...

# %%
# !fairbio-trs -r https://api.biocontainers.pro/ tools -o biocontainers_software.json --all
# Out:
# 🔍 Fetching ALL tools from https://api.biocontainers.pro/...
#    (This may take a while, automatically paginating through all results...)
# Error fetching tools: HTTPSConnectionPool(host='api.biocontainers.pro', port=443): Read timed out. (read timeout=10)
# ✓ Found 0 tools
# 💾 Saved to biocontainers_software.json
#
# 📋 Tools Summary:
#
# 📄 Pagination Summary:
#   Total Tools: 1 pages retrieved
#   Page Size: 1000

# %% [markdown]
# # Array of Versions

# %%
import json
versions = []
with open('biocontainers_software.json') as f:
    tools = json.load(f)
    for tool in tools.get("tools", []):
        for v in tool.get("versions", []):
            versions.append(v)

# %% [markdown]
# # Array of unique software names

# %%
software = []
with open('biocontainers_software.json') as f:
    tools = json.load(f)
    for tool in tools.get("tools", []):
        software.append(tool.get("id"))

# %% [markdown]
# # Download Software Ontology

# %%
import requests
import json

github_json_url = "https://raw.githubusercontent.com/allysonlister/swo/master/swo-full.json"
output_filename = "swo-full.json"

print(f"Attempting to download JSON from {github_json_url}...")

try:
    response = requests.get(github_json_url, timeout=30) # Added a 30-second timeout
    response.raise_for_status() # Raise an HTTPError for bad responses (4xx or 5xx)

    swo_data = response.json()
    with open(output_filename, "w") as f:
        json.dump(swo_data, f, indent=4)
    print(f"Successfully downloaded and saved JSON to {output_filename}")

except requests.exceptions.HTTPError as errh:
    print(f"HTTP Error: {errh}")
    print(f"Response status code: {response.status_code}")
    print(f"Response content: {response.text[:500]}...")
except requests.exceptions.ConnectionError as errc:
    print(f"Error Connecting: {errc}")
except requests.exceptions.Timeout as errt:
    print(f"Timeout Error: {errt}. The request took too long to respond.")
except requests.exceptions.RequestException as err:
    print(f"An unexpected error occurred: {err}")
# Out:
# Attempting to download JSON from https://raw.githubusercontent.com/allysonlister/swo/master/swo-full.json...
# Successfully downloaded and saved JSON to swo-full.json

# %%
software
# Out:
# []

# %%
# !pip install ontogpt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.0/64.0 kB 7.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.3/455.3 kB 28.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.4/444.4 kB 47.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 12.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.4/14.4 MB 80.2 MB/s eta 0:00:00
# ...

# %%
# !pip install requests==2.32.4
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.8/64.8 kB 6.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.5
#     Uninstalling requests-2.32.5:
#       Successfully uninstalled requests-2.32.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pysolr 3.11.0 requires requests>=2.32.5, but you have requests 2.32.4 which is incompatible.
# ...

# %% [markdown]
# # Ollama Install

# %%
# !sudo apt update
# !sudo apt-get install -y zstd
# !sudo apt install -y pciutils
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 121 packages can be upgraded. Run 'apt list --upgradable' to see them.
# ...

# %%
import threading
import subprocess
import time

def run_ollama_serve():
  subprocess.Popen(["ollama", "serve"])

thread = threading.Thread(target=run_ollama_serve)
thread.start()
time.sleep(5)

# %%
# !ollama pull llama3.2

# %%
# !pip install ontogpt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.0/64.0 kB 7.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.3/455.3 kB 19.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.4/444.4 kB 43.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.4/14.4 MB 104.7 MB/s eta 0:00:00
# ...

# %%
# !echo "2pg_cartesian" > example.txt

# %%
# !ontogpt extract -i example.txt -t datasheet --model ollama/llama3.2
# Out:
# ERROR:ontogpt.clients.llm_client:API connection error: litellm.APIConnectionError: OllamaException - [Errno 111] Connection refused
# ERROR:ontogpt.clients.llm_client:No response or response is empty.
# ---
# input_text: |
#   2pg_cartesian
# prompt: |+
#   From the text below, extract the following entities in the following format:
#
#   name: <The name of the dataset.>
#   subsets: <Semicolon-separated list of names of any subsets of the dataset.>
#   authors: <Semicolon-separated list of names of creators of the dataset.>
#   funding_organization: <Semicolon-separated list of organizations supporting creation of the dataset.>
#   funding_identifiers: <Semicolon-separated list of names, numbers, or other identifiers for grants supporting creation of the dataset.>
#   purpose: <The stated purpose of the dataset. This should be no more than 1 sentence.>
#   limitations: <Known limitations of the dataset. This should be no more than 1 sentence.>
# ...

# %%
# !ontogpt list-templates
# Out:
# ID	Name	Description
# adverse_outcome_pathway	adverse_outcome_pathway	Template for extracting Adverse Outcome Pathways (AOPs) from literature. AOPs are conceptual frameworks  that link a molecular initiating event to an adverse outcome through a series of key events.
# all_disease_grounding	all_disease_grounding	Template for grounding disease names
# alzrd	alzrd	Template for extracting phenotypes of Alzheimer's disease and related dementias along with experimental metrics and model organisms. Assumes a large input text, on the order of a full scientific article or review. Focus is on extracting the methods and metrics used with different model organisms. This version of the template attempts to process the entirety of the input text at once.
# ...
